# %%
# from dbfread import DBF
import pandas as pd
# Koneksi Postgress``
# import sqlalchemy as db

# %%
data = {
    "name":[100,200],
    "key":[222,55]
    }

# %%
data

# %%
excel = pd.read_excel("14 Indeks Desa 2021 Menurut Desa Kepmen 146 Tahun 2020.xlsx",header=2)

# %%
excel

# %%
# Fitur Upload File

namaFile = 'XBase.dbf'
nameFile = namaFile.rsplit(".", 1)[0] 
print(nameFile)

# %%
# Transformasi Ke Dataframe
dbf = DBF(namaFile)
dbf = pd.DataFrame(dbf)

dbf.head()

# %%
username = "postgres"
password = 12345
host = "localhost:5432"
dbName = "DbTest"

# %%
def connectDatabase(dbName):
    engine = db.create_engine(f'postgresql://{username}:{password}@{host}/{dbName}')
    return engine

# %%
mesin = connectDatabase('DbTest')
with mesin.connect() as conn:
    print(f"berhasil terhubung dengan database")

query = db.text("SELECT datname FROM pg_database WHERE datistemplate = false;")
result = mesin.connect().execute(query)
databases = [row[0] for row in result]
print(databases)

# %%
# Insert TO Postgres
dbf.to_sql(name='example',con=engine, if_exists='replace', index=False)

# %%
query = db.text("SELECT datname FROM pg_database WHERE datistemplate = false;")
result = engine.connect().execute(query)

# %%
databases = [row[0] for row in result]

# %%
# Read .SAV File with Pandas
dfStat  = pd.read_spss('14_sak202508_10_part1.sav')

# %%
df

# %%
# Read .SAV File with pyreadstat
import pyreadstat
df, metadata = pyreadstat.read_sav('14_sak202508_10_part1.sav')

# %%
print(df.head())

# %%
print(metadata.column_names_to_labels)

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# Hubungkan ke database bawaan 'postgres'
engine = create_engine("postgresql://postgres:postgres@10.14.0.12:5432/postgres")

# Jalankan perintah CREATE DATABASE di dalam blok koneksi
with engine.connect() as conn:
    # Memastikan eksekusi tidak berada dalam transaksi (autocommit mode)
    conn = conn.execution_options(isolation_level="AUTOCOMMIT")
    conn.execute(text("CREATE DATABASE namadatabasebaru;"))
    print("Database berhasil dibuat!")
# Out:
# Database berhasil dibuat!

# %%
import pandas as pd

df = pd.read_csv('Data Science - MetadaDatabase.csv')

# %%
df["Nama Sekarang"]
# Out:
# 0          2025_03_Susenas_KP
# 1          2024_03_Susenas_KP
# 2         2024_03_Susenas_Kor
# 3          2023_03_Susenas_KP
# 4     2023_03_Susenas_Kor_Rev
# 5         2022_09_Susenas_MKP
# 6          2022_09_Susenas_KP
# 7          2022_03_Susenas_KP
# 8     2022_03_Susenas_Kor_Rev
# 9          2021_09_Susenas_Kp
# 10     2021_03_Susenas_Kor_Kp
# 11            2020_09_Susenas
# 12     2020_03_Susenas_Kor_Kp
# 13        2019_03_Susenas_Kor
# 14        2018_03_Susenas_Kor
# 15        2017_03_Susenas_Kor
# 16        2016_03_Susenas_Kor
# 17        2015_03_Susenas_Kor
# 18        2026_02_Sakernas_10
# 19    2025_02_Sakernas_15_Rev
# 20        2025_02_Sakernas_10
# 21        2025_08_Sakernas_10
# 22        2025_08_Sakernas_15
# 23        2025_11_Sakernas_15
# 24        2025_11_Sakernas_10
# 25        2024_02_Sakernas_15
# 26        2024_08_Sakernas_10
# 27        2024_08_Sakernas_15
# 28        2023_02_Sakernas_10
# 29        2023_08_Sakernas_10
# 30        2023_08_Sakernas_15
# ...
